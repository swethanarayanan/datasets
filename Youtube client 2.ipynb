# %%
# import os

# from googleapiclient.discovery import build
# from googleapiclient.errors import HttpError

# # The CLIENT_SECRETS_FILE variable specifies the name of a file that contains
# # the OAuth 2.0 information for this application, including its client_id and
# # client_secret.
# CLIENT_SECRETS_FILE = "client_secret.json"

# API_SERVICE_NAME = 'youtube'
# API_VERSION = 'v3'
# DEVELOPER_KEY = "AIzaSyClCm3-soffyi6P7vkgXcNe02KmLhI1NN4"


# def youtube_search(q, max_results=1,order="relevance", token=None, location=None, location_radius=None):

#     youtube = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION,developerKey=DEVELOPER_KEY)

#     search_response = youtube.search().list(
#     q=q,
#     type="video",
#     pageToken=token,
#     order = order,
#     part="id,snippet", # Part signifies the different types of data you want 
#     maxResults=max_results,
#     location=location,
#     locationRadius=location_radius).execute()

#     title = []
#     channelId = []
#     channelTitle = []
#     categoryId = []
#     videoId = []
#     viewCount = []
#     likeCount = []
#     dislikeCount = []
#     commentCount = []
#     favoriteCount = []
#     category = []
#     tags = []
#     videos = []
    
#     for search_result in search_response.get("items", []):
#         if search_result["id"]["kind"] == "youtube#video":

#             title.append(search_result['snippet']['title']) 

#             videoId.append(search_result['id']['videoId'])

#             response = youtube.videos().list(
#                 part='statistics, snippet',
#                 id=search_result['id']['videoId']).execute()

#             channelId.append(response['items'][0]['snippet']['channelId'])
#             channelTitle.append(response['items'][0]['snippet']['channelTitle'])
#             categoryId.append(response['items'][0]['snippet']['categoryId'])
#             favoriteCount.append(response['items'][0]['statistics']['favoriteCount'])
#             viewCount.append(response['items'][0]['statistics']['viewCount'])
#             likeCount.append(response['items'][0]['statistics']['likeCount'])
#             dislikeCount.append(response['items'][0]['statistics']['dislikeCount'])
 
#         if 'commentCount' in response['items'][0]['statistics'].keys():
#             commentCount.append(response['items'][0]['statistics']['commentCount'])
#         else:
#             commentCount.append([])
 
#         if 'tags' in response['items'][0]['snippet'].keys():
#             tags.append(response['items'][0]['snippet']['tags'])
#         else:
#             tags.append([])

#     youtube_dict = {'tags':tags,'channelId': channelId,'channelTitle': channelTitle,'categoryId':categoryId,'title':title,'videoId':videoId,'viewCount':viewCount,'likeCount':likeCount,'dislikeCount':dislikeCount,'commentCount':commentCount,'favoriteCount':favoriteCount}

#     return youtube_dict

# %%
import pandas as pd

# %%
dfs = pd.read_excel("Trailers.xlsx")

# %%
remaining = pd.read_excel("Youtube_remaining.xlsx")

# %%
dfs.head(1)
# Out:
#    IMDB_ID                             Name  num_ratings  avg_rating  \
# 0    62456  Voyna i mir IV: Pierre Bezukhov        691.0         8.3
#
#                                       main_cast_list  \
# 0  Sergey Bondarchuk|Vyacheslav Tikhonov|Lyudmila...
#
#                                      main_cast_links           dir_list  \
# 0  /name/nm0094083/|/name/nm0863146/|/name/nm0767...  Sergey Bondarchuk
#
#                                      creator_list  genre  \
# 0  Leo Tolstoy|Sergey Bondarchuk|Vasiliy Solovyov  Drama
#
#   motion_picture_rating      ...      num_user_ratings num_critic_ratings  \
# 0             Not Rated      ...                   NaN                NaN
#
#                                           story_line  \
# 0      The 500,000 strong Napoleon's army moves t...
#
#                                               others   id  Youtubelink  \
# 0  {u'Alternate Versions': u'\nAlternate Versions...  0.0  3DqanxfecIA
#
# ...

# %%
remaining.head(1)
# Out:
#    IMDB_ID                Name  num_ratings  avg_rating  \
# 0   938283  The Last Airbender       136569         4.1
#
#                               main_cast_list  \
# 0  Noah Ringer|Nicola Peltz|Jackson Rathbone
#
#                                      main_cast_links            dir_list  \
# 0  /name/nm3226241/|/name/nm2443758/|/name/nm1717...  M. Night Shyamalan
#
#          creator_list                                 genre  \
# 0  M. Night Shyamalan  [Action, Adventure, Family, Fantasy]
#
#   motion_picture_rating                        ...                          \
# 0                    PG                        ...
#
#    duration meta_critic_score  num_user_ratings  num_critic_ratings  \
# 0  1h 43min              20.0               1.0               283.0
#
#                                           story_line  \
# 0      The world is divided into four kingdoms, e...
#
#                                               others         Gross Country  \
# ...

# %%
merged = pd.merge(remaining, dfs, on = 'Name', how = 'left')

# %%
merged[merged.Name == 'Just Before I Go']
# Out:
#      IMDB_ID_x              Name  num_ratings_x  avg_rating_x  \
# 870    2980472  Just Before I Go          16466           6.4
#
#                                       main_cast_list_x  \
# 870  Seann William Scott|Olivia Thirlby|Garret Dill...
#
#                                      main_cast_links_x     dir_list_x  \
# 870  /name/nm0005405/|/name/nm1880888/|/name/nm0226...  Courteney Cox
#
#      creator_list_x          genre_x motion_picture_rating_x     ...       \
# 870  David Flebotte  [Comedy, Drama]                       R     ...
#
#     num_user_ratings_y num_critic_ratings_y  \
# 870               68.0                 17.0
#
#                                           story_line_y  \
# 870      Ted Morgan has been treading water for mos...
#
#                                               others_y      id  Youtubelink  \
# 870  {u'Filming Locations:': u'\nFilming Locations:...  5808.0  LoGzbn_HVsA
#
#      viewCount likeCount dislikeCount commentCount
# ...

# %%
#new_df = pd.DataFrame()
# res = []
# for i in response['items']:
#  temp_res = dict(v_id = i['id'])
#  temp_res.update(i['statistics'])
#  res.append(temp_res)
#pd.DataFrame.from_dict(res)

# %%
# def get_authenticated_service():
#   flow = InstalledAppFlow.from_client_secrets_file(CLIENT_SECRETS_FILE, SCOPES)
#   credentials = flow.run_console()
#   return build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION, credentials = credentials)

# def youtube_search_id_oauth(q, max_results=1,order="relevance", token=None, location=None, location_radius=None):

#     os.environ['OAUTHLIB_INSECURE_TRANSPORT'] = '1'
#     client = get_authenticated_service()

#     search_response = youtube.search().list(
#     q=q,
#     type="video",
#     pageToken=token,
#     order = order,
#     part="id", # Part signifies the different types of data you want 
#     maxResults=max_results,
#     location=location,
#     locationRadius=location_radius).execute()
    
#     videoId = []
    
#     for search_result in search_response.get("items", []):
#         if search_result["id"]["kind"] == "youtube#video":
#             videoId.append(search_result['id']['videoId'])
        
#     youtube_dict = {'videoId':videoId}

#     return youtube_dict
